# %% [markdown]
# ## Setting up the Environment
#
# In this section, we'll prepare the environment.
#
# You need:
#
# * **Python 3.11** (note that videos use 3.8)
# * **NumPy**, **Pandas**, and **Scikit-Learn** (latest available versions)
# * **Matplotlib** and **Seaborn**
# * **Jupyter Notebooks**
#
# ---
#
# ## Github Codespaces
#
# **Video:** [Setting up Codespaces](https://www.youtube.com/watch?v=pqQFlV3f9Bo&list=PL3MmuxUbc_hIhxl5Ji8t4O6lPAOpHaCLR)
#
# > This is the recommended approach for the course.
#
# ---
#
# ## Ubuntu 22.04 on AWS
#
# * [Complete AWS setup video](https://www.youtube.com/watch?v=IXSiYkP23zo) — shows an end-to-end configuration for an AWS EC2 instance
# ---
#
# ## Anaconda and Conda
#
# The easiest way to set up the environment is to use
# [**Anaconda**](https://www.anaconda.com/products/individual) or [**Miniconda**](https://docs.conda.io/en/latest/miniconda.html).
#
# * **Anaconda** comes with everything we need (and much more).
# * **Miniconda** is a smaller version containing only Python.
#
# Follow the instructions on the respective pages to install the correct package for your system.
# The site will automatically detect your OS and suggest the right installer.
#
# * [Download Anaconda](https://www.anaconda.com/products/individual)
# * [Download Miniconda](https://docs.conda.io/en/latest/miniconda.html#latest-miniconda-installer-links)
#
# > **Anaconda is recommended.**
# ---
#
# ### (Optional) Create environment for course
#
# It’s a good idea to create a **dedicated environment** for this course.
#
# In your terminal, run:
#
# ```bash
# conda create -n ml-zoomcamp python=3.11
# ````
#
# Activate it:
#
# ```bash
# conda activate ml-zoomcamp
# ```
#
# Then install the libraries:
#
# ```bash
# conda install numpy pandas scikit-learn seaborn jupyter
# ```
#
# > Later in the course, you'll also need **XGBoost** and **TensorFlow**, but we can skip those for now.
#
#
#
# ---
#
# ## Notebook Services
#
# There are services that allow you to **host and run notebooks** online.
# However, note that notebooks alone are **not sufficient** for the course — for deployment modules, you'll need **command-line access** with Docker, Python, and other tools installed.
#
# ---
